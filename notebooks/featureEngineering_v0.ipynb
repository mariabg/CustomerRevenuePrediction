# %% [markdown]
# ## Turn this into a good looking informative cell
# #### The output .csv file will contain the following fields
#     - channelGrouping
#     - fullVisitorId
#     - visitId
#     - visitNumber
#     - visitStartTime
#     - browser
#     - deviceCategory
#     - operatingSystem
#     - city
#     - country
#     - region
#     - subContinent
#     - hits
#     - newVisits
#     - *timeOnSite*
#     - totalTransactionRevenue
#     - *transactions dividir esto*
#     - adHasContent
#     - adPosition
#     - campaign
#     - isTrueDirect
#     - medium
#     - source

# %%
import pandas as pd
import glob
import json
import numpy as np

pd.set_option('display.max_columns', 30)

# %%
# recursive flatten function from https://towardsdatascience.com/flattening-json-objects-in-python-f5343c794b10
# Call example:
  # flattenCol = [flatten_json(json.loads(d)) for d in df['trafficSource']]
  # dataFrameOfFlattenCol = pd.DataFrame(flattenCol)
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
# bash commands for splitting a huge dataset into several smaller ones
dataPath = "../data/splitted_train/*.csv"
# !mkdir tempSplittedData
# !split -l 100000 dataPath
# !head -n 1 dataPath > headerfile
# !for csv! in *.csv; do cat headerfile $csv > tmpfile2; mv tmpfile2 $csv; done
# !rm headerfile
# !rm -r tempSplittedData
# TO DO
# Out:
# split: dataPath: No such file or directory
# head: dataPath: No such file or directory
# /bin/sh: `csv!': not a valid identifier

# %%
allFiles = glob.glob("../data/train_v2.csv")
df = pd.DataFrame({'channelGrouping': [],
                    'device': [],
                    'fullVisitorId': [],
                    'geoNetwork': [],
                    'socialEngagementType': [],
                    'totals': [],
                    'trafficSource': [],
                    'visitNumber': [],
                    'visitStartTime': []})

for fl in allFiles:
    temp = pd.read_csv(fl, usecols=["channelGrouping", "date", "device", "fullVisitorId", "geoNetwork",
                                      "socialEngagementType", "totals", "trafficSource", "visitId", "visitNumber",
                                      "visitStartTime"], header=0, dtype={'fullVisitorId': 'str'})
    # we leave out hits, customDimensions and date
    temp.drop(columns=["date", "visitId"], axis=1, inplace=True)
    df = df.append(temp, ignore_index=True)

# %%
df.describe(include='all')
# Out:
#        channelGrouping                                             device  \
# count          1708337                                            1708337
# unique               8                                                298
# top     Organic Search  {"browser": "Chrome", "browserVersion": "not a...
# freq            738963                                             504589
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#               fullVisitorId  \
# count               1708337
# unique              1323730
# top     1957458976293878100
# freq                    400
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                                geoNetwork  \
# count                                             1708337
# unique                                              59955
# top     {"continent": "Americas", "subContinent": "Nor...
# freq                                               132962
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         socialEngagementType  \
# count                1708337
# unique                     1
# top     Not Socially Engaged
# freq                 1708337
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
#
#                                                    totals  \
# count                                             1708337
# unique                                             252374
# top     {"visits": "1", "hits": "1", "pageviews": "1",...
# freq                                               350177
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             trafficSource   visitNumber  \
# count                                             1708337  1.708337e+06
# unique                                              76637           NaN
# top     {"campaign": "(not set)", "source": "google", ...           NaN
# freq                                               460901           NaN
# mean                                                  NaN  2.335170e+00
# std                                                   NaN  9.354034e+00
# min                                                   NaN  1.000000e+00
# 25%                                                   NaN  1.000000e+00
# 50%                                                   NaN  1.000000e+00
# 75%                                                   NaN  1.000000e+00
# max                                                   NaN  4.570000e+02
#
#         visitStartTime
# count     1.708337e+06
# unique             NaN
# top                NaN
# freq               NaN
# mean      1.498352e+09
# std       1.624937e+07
# min       1.470035e+09
# 25%       1.482738e+09
# 50%       1.499832e+09
# 75%       1.512513e+09
# max       1.525158e+09

# %%
df.head(5)
# Out:
#   channelGrouping                                             device  \
# 0  Organic Search  {"browser": "Firefox", "browserVersion": "not ...
# 1        Referral  {"browser": "Chrome", "browserVersion": "not a...
# 2          Direct  {"browser": "Chrome", "browserVersion": "not a...
# 3  Organic Search  {"browser": "Chrome", "browserVersion": "not a...
# 4  Organic Search  {"browser": "Chrome", "browserVersion": "not a...
#
#          fullVisitorId                                         geoNetwork  \
# 0  3162355547410993243  {"continent": "Europe", "subContinent": "Weste...
# 1  8934116514970143966  {"continent": "Americas", "subContinent": "Nor...
# 2  7992466427990357681  {"continent": "Americas", "subContinent": "Nor...
# 3  9075655783635761930  {"continent": "Asia", "subContinent": "Western...
# 4  6960673291025684308  {"continent": "Americas", "subContinent": "Cen...
#
#    socialEngagementType                                             totals  \
# 0  Not Socially Engaged  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  Not Socially Engaged  {"visits": "1", "hits": "2", "pageviews": "2",...
# 2  Not Socially Engaged  {"visits": "1", "hits": "2", "pageviews": "2",...
# 3  Not Socially Engaged  {"visits": "1", "hits": "2", "pageviews": "2",...
# 4  Not Socially Engaged  {"visits": "1", "hits": "2", "pageviews": "2",...
#
#                                        trafficSource  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...          1.0
# 1  {"referralPath": "/a/google.com/transportation...          6.0
# 2  {"campaign": "(not set)", "source": "(direct)"...          1.0
# 3  {"campaign": "(not set)", "source": "google", ...          1.0
# 4  {"campaign": "(not set)", "source": "google", ...          1.0
#
#    visitStartTime
# 0    1.508198e+09
# 1    1.508176e+09
# 2    1.508202e+09
# 3    1.508170e+09
# 4    1.508191e+09

# %%
df.shape
# Out:
# (1708337, 9)

# %%
# df = df.replace({
# MERGED    "(not set)": np.nan,                  "(none)": np.nan,
#               KEPT   "not available in demo dataset": np.nan})

# %%
# De misc mantenemos:
  # fullVisitorId
  # visitStartTime
  # channelGrouping

df["visitStartTime"] = pd.to_datetime(df["visitStartTime"], unit='s')
df.drop(['socialEngagementType'], axis=1, inplace=True)

print(list(df))
# Out:
# ['channelGrouping', 'device', 'fullVisitorId', 'geoNetwork', 'totals', 'trafficSource', 'visitNumber', 'visitStartTime']

# %%
# De device mantenemos:
  # browser
  # deviceCategory
  # operatingSystem

deviceFlatten = [flatten_json(json.loads(d)) for d in df['device']]

devi = pd.DataFrame(deviceFlatten)

devi.drop(columns=['browserSize', 'browserVersion', 'flashVersion', 'language', 
    'mobileDeviceBranding', 'mobileDeviceInfo', 'mobileDeviceMarketingName',
    'mobileDeviceModel', 'mobileInputSelector', 'operatingSystemVersion',
    'screenColors','screenResolution'], inplace=True)

#we map our data to its corresponding value
isMobile = {False : 0, True : 1}
devi["isMobile"] = devi["isMobile"].map(isMobile)

devi.drop(columns=['isMobile'], inplace=True, axis=1)
df.drop(columns=['device'], inplace=True, axis=1)
df = df.join(devi)

print(list(df))
# Out:
# ['channelGrouping', 'fullVisitorId', 'geoNetwork', 'totals', 'trafficSource', 'visitNumber', 'visitStartTime', 'browser', 'deviceCategory', 'operatingSystem']

# %%
# De geoNetwork mantenemos:
  # subcontinent
  # coutry
  # region (que contiene ciudad si no está disponible)
  # city

geoNetworkFlatten = [flatten_json(json.loads(d)) for d in df['geoNetwork']]
geo = pd.DataFrame(geoNetworkFlatten)
geo.drop(['latitude','longitude','networkLocation','cityId','continent','metro', 'networkDomain'], axis=1, inplace=True)

def region_country(geo):
    if geo['region'] == '(not set)':
        return geo['country']
    elif geo['region'] == 'not available in demo dataset':
        return geo['country']
    else:
        return geo['region']
    
geo['region']=geo.apply(region_country,axis=1)
# geo.loc[geo['city'] == "not available in demo dataset",'city'] = np.nan

# geo['region'].fillna(geo['country'])

df.drop(columns=['geoNetwork'], inplace=True, axis=1)
df = df.join(geo)

# %%
list(df)
# Out:
# ['channelGrouping',
#  'fullVisitorId',
#  'totals',
#  'trafficSource',
#  'visitNumber',
#  'visitStartTime',
#  'browser',
#  'deviceCategory',
#  'operatingSystem',
#  'city',
#  'country',
#  'region',
#  'subContinent']

# %%
# De totals mantenemos:
  # hits
  # transactionRevenue
  # newVisits

#Transform json
totalsList = [flatten_json(json.loads(d)) for d in df['totals']]
totals_df = pd.DataFrame(totalsList)

#Remove visits column as it does not provide any information
# Remove sessionQualityDim: An estimate of how close a particular session was to transacting, ranging
    # from 1 to 100, calculated for each session. A value closer to 1 indicates a low session quality, or
    # far from transacting, while a value closer to 100 indicates a high session quality, or very close to
    # transacting. A value of 0 indicates that Session Quality is not calculated for the selected time range.
# Remove transactionRevenue (deprecated) to use totalTransactionRevenue instead
totals_df = totals_df.drop(['visits', 'sessionQualityDim', 'transactionRevenue', 'hits', 'newVisits'], axis=1)

#Change nan in "transactionRevenue" for 0. 
totals_df['totalTransactionRevenue'] = totals_df['totalTransactionRevenue'].fillna(0)

#Change nan in "bounces" for 0
totals_df['bounces'] = totals_df['bounces'].fillna(0)

#There are some nan in pageviews but it is not trivial to find a value we can change these nan by logically.
#The corrlation with hits is 0.984, so we can keep hits that does not have any nan value. Keeping both could be redundant.
totals_df = totals_df.drop(['pageviews'], axis=1)

#Not 100% proven yet, but i have a big feeling that bounces is mainly 1 when there is only 1 hit by defenition.
#This means that even though the correlation doesn't provide a big value beetween them two, bounces is not giving much 
#additional info. Meaning using it is not relevant.
totals_df = totals_df.drop(['bounces'], axis=1)

totals_df['totalTransactionRevenue'] = totals_df['totalTransactionRevenue'].apply(lambda x: float(x)/1000000)

df.drop(['totals'], inplace=True, axis=1)
df = df.join(totals_df)
# df = pd.concat([df, totals_df])

# %%
trafficFlatten = [flatten_json(json.loads(d)) for d in df['trafficSource']]
traffic = pd.DataFrame(trafficFlatten)

# %%
workingdf = traffic.copy()

workingdf.drop(['adwordsClickInfo_criteriaParameters', 'adwordsClickInfo_adNetworkType',
    'adwordsClickInfo_gclId', 'adwordsClickInfo_isVideoAd', 'adwordsClickInfo_page',
    'keyword', 'referralPath'], axis=1, inplace=True)

# workingdf['campaign'].value_counts()

# workingdf.sample(10)
# workingdf.describe()
workingdf['source'].value_counts()
# Out:
# google                         658384
# (direct)                       565975
# youtube.com                    329450
# analytics.google.com            37436
# Partners                        32931
# sites.google.com                 9072
# google.com                       8341
# m.facebook.com                   6737
# dfa                              6704
# baidu                            4971
# reddit.com                       4092
# facebook.com                     3584
# googleads.g.doubleclick.net      3539
# qiita.com                        3394
# bing                             3368
# quora.com                        3032
# mail.google.com                  2558
# yahoo                            2436
# siliconvalley.about.com          2097
# groups.google.com                2009
# t.co                             2005
# l.facebook.com                   1529
# blog.golang.org                  1382
# dealspotr.com                     750
# support.google.com                676
# productforums.google.com          672
# plus.google.com                   650
# google.co.jp                      641
# away.vk.com                       613
# docs.google.com                   578
#                                 ...
# ps-dm.reddit.com                    1
# google.iq                           1
# images.google.at                    1
# images.google.com.br                1
# search.mywebsearch.com              1
# qc.search.yahoo.com                 1
# images.google.co.in                 1
# google.lt                           1
# info.com                            1
# us.reddit.com                       1
# apps.rackspace.com                  1
# google.bg                           1
# newsstand.google.com                1
# google.com.ar                       1
# google.ie                           1
# intranet                            1
# developers.google.com               1
# images.google.com.au                1
# tumblr.com                          1
# es.yhs4.search.yahoo.com            1
# google.com.bd                       1
# google.ro                           1
# p.qiao.baidu.com                    1
# mobile.facebook.com                 1
# hosted.verticalresponse.com         1
# start.wow.com                       1
# google.lv                           1
# computerworld.com                   1
# yahoo.com                           1
# id.pinterest.com                    1
# Name: source, Length: 345, dtype: int64

# %%
# df['campaign'].value_counts()

# %%
workingdf['campaign'].value_counts()
# Out:
# (not set)                                                               1604526
# Data Share Promo                                                          32914
# 1000557 | GA | US | en | Hybrid | GDN Text+Banner | AS                    24410
# 1000557 | GA | US | en | Hybrid | GDN Remarketing                         15149
# AW - Dynamic Search Ads Whole Site                                        15146
# AW - Accessories                                                           7972
# Smart Display Campaign                                                     2664
# "google + redesign/Accessories March 17" All Users Similar Audiences       1179
# Page: contains "/google+redesign/drinkware" Similar Audiences               611
# "google + redesign/Accessories March 17" All Users                          562
# Sports & Fitness/Health & Fitness Buffs                                     463
# Run of Network Line Item                                                    428
# Media & Entertainment/Movie Lovers                                          311
# Technology/Mobile Enthusiasts                                               310
# Technology/Technophiles                                                     290
# Value Shoppers Affinity                                                     208
# Media & Entertainment/Music Lovers                                          195
# Page: contains "/google+redesign/drinkware"                                 192
# Page: contains "/google+redesign/office" Similar Audiences                  182
# Lifestyles & Hobbies/Shutterbugs                                            131
# Page: contains "/google+redesign/electronics"                                97
# Page: contains "/google+redesign/office"                                     93
# Page: contains "/google+redesign/bags" All Users                             83
# AW - Electronics                                                             75
# AW - Apparel                                                                 44
# Page: contains "/google+redesign/bags" All Users Similar Audiences           42
# Page: contains "/google+redesign/bags" 1 Day                                 27
# (direct)                                                                     12
# Page: contains "/google+redesign/electronics" Similar Audiences               9
# "google + redesign/Accessories March 17" 1 Day                                5
# All Products                                                                  4
# Gmail type campaign                                                           2
# Data Share                                                                    1
# Name: campaign, dtype: int64

# %%
# De trafficSource mantenemos:
  # adContent
  # adPosition
  # campaign
  # isTrueDirect
  # medium
  # source

trafficFlatten = [flatten_json(json.loads(d)) for d in df['trafficSource']]
traffic = pd.DataFrame(trafficFlatten)
traffic.drop(['adwordsClickInfo_criteriaParameters', 'adwordsClickInfo_adNetworkType',
    'adwordsClickInfo_gclId', 'adwordsClickInfo_isVideoAd', 'adwordsClickInfo_page',
    'keyword', 'referralPath'], axis=1, inplace=True)

# rename to a simpler name
traffic.rename(index=str, columns={
    "adwordsClickInfo_slot": "adPosition"}, inplace=True)

df['adContent'] = traffic['adContent'].copy()
df['adPosition'] = traffic['adPosition'].copy()
df['campaign'] = traffic['campaign'].copy()
df['isTrueDirect'] = traffic['isTrueDirect'].copy()
df['medium'] = traffic['medium'].copy()
df['source'] = traffic['source'].copy()

# TO DO: traffic['source'] regex for the main domain (last whatevs.com), and drop less than 1000
# traffic['source'] = traffic['source'].str.extract('{"browser": "(.+?)"', expand=True)

# df.drop(columns=['trafficSource'], inplace=True, axis=1)
# df = df.join(traffic)
# df = merge(df, traffic)

# %%
# df.drop(columns=['campaign'], inplace=True, axis=1)
# df['campaign'] = traffic['campaign'].copy()
# df['position'] = traffic['adPosition'].copy()
# df['position'].value_counts()

# %%
# De trafficSource mantenemos:
  # adContent
  # adPosition
  # campaign
  # isTrueDirect
  # medium
  # source

trafficFlatten = [flatten_json(json.loads(d)) for d in df['trafficSource']]
traffic = pd.DataFrame(trafficFlatten)
traffic.drop(['adwordsClickInfo_criteriaParameters', 'adwordsClickInfo_adNetworkType',
    'adwordsClickInfo_gclId', 'adwordsClickInfo_isVideoAd', 'adwordsClickInfo_page',
    'keyword', 'referralPath'], axis=1, inplace=True)

# rename to a simpler name
traffic.rename(index=str, columns={
    "adwordsClickInfo_slot": "adPosition"}, inplace=True)

# TO DO: traffic['source'] regex for the main domain (last whatevs.com), and drop less than 1000
# traffic['source'] = traffic['source'].str.extract('{"browser": "(.+?)"', expand=True)

# df.drop(columns=['trafficSource'], inplace=True, axis=1)
# df = df.join(traffic)
# df = merge(df, traffic)

# %%
df.drop(columns=['adContent', 'adPosition', 'campaign', 'isTrueDirect', 'medium', 'source'], inplace=True, axis=1)

# %%
a = traffic.join(df)

# %%
df = a.copy()

# %%
df['adContent'].value_counts()
# Out:
# Google Merchandise Store                       39566
# Google Merchandise Collection                   6762
# Placement Accessores 300 x 250                  3040
# Smart display ad - 8/17/2017                    2664
# Display Ad created 3/11/14                      2344
# Google Online Store                             1773
# Official Google Merchandise                      866
# Ad from 12/15/17                                 853
# Full auto ad IMAGE ONLY                          822
# Placement Drinkware 300x250                      653
# Ad from 12/13/16                                 610
# Ad from 11/3/16                                  489
# {KeyWord:Google Brand Items}                     418
# Display Ad created 3/11/15                       392
# Placement Accessories 336 x 280                  308
# BQ                                               287
# Placement Accessories 300 x 250                  280
# {KeyWord:Google Merchandise}                     274
# Placement Accessories 160 x 600                  261
# Placement Elecronics 300 x 250                   190
# Placement 300 x 250                              159
# Swag with Google Logos                           147
# Ad from 11/7/16                                  123
# Drinkware 336x280                                 96
# {KeyWord:Google Branded Gear}                     95
# Bags 300x250                                      90
# {KeyWord:Looking for Google Bags?}                89
# Google Merchandise                                87
# First Full Auto Template Test Ad                  87
# Placement Office 300x250                          80
#                                                ...
# Placement Office 336x280                          15
# Office Placement 160x600                          14
# Bags 160 x 600                                    13
# Accessories Placement 336 x 280                   13
# {KeyWord:Want Google Pet Toys?}                   11
# {KeyWord:Google Branded Apparel}                  10
# Want Google Sunglasses                             9
# test_tyler_hr_merchant                             8
# Google Store                                       8
# Google Paraphernalia                               8
# Full auto ad TEXT/NATIVE                           7
# visit us again                                     7
# Office 2018 - 120 x 600                            7
# Drinkware 120x600                                  6
# {KeyWord:Google Branded Outerwear}                 5
# Official Google Merchandise - Fast Shipping        4
# url_builder                                        3
# Men's-Outerwear Google Apparel                     3
# Ad from 2/17/17                                    3
# Full auto ad with Primary Color                    3
# Full auto ad NATIVE ONLY                           3
# free shipping                                      3
# cool                                               2
# google store                                       2
# Google store                                       2
# Free Shipping!                                     2
# Google Apparel                                     1
# Men's Apparel from Google                          1
# Swag w/ Google Logos                               1
# GA Help Center                                     1
# Name: adContent, Length: 76, dtype: int64

# %%
list(df)
# Out:
# ['adContent',
#  'adPosition',
#  'campaign',
#  'campaignCode',
#  'isTrueDirect',
#  'medium',
#  'source',
#  'channelGrouping',
#  'fullVisitorId',
#  'trafficSource',
#  'visitNumber',
#  'visitStartTime',
#  'browser',
#  'deviceCategory',
#  'operatingSystem',
#  'city',
#  'country',
#  'region',
#  'subContinent',
#  'timeOnSite',
#  'totalTransactionRevenue',
#  'transactions',
#  'position']

# %%
print(df.shape)
print(df['adContent'].count())
# Out:
# (1708337, 23)
# 64737

# %%
# df = df.replace({"(not set)": np.nan,
#                  "(none)": np.nan,
#                  "not available in demo dataset": np.nan})

# %%
df.describe(include='all')

# %%
df.head(5)

# %%
df[df['isTrueDirect'].isna()==False]
# Out:
#         adContent adPosition   campaign campaignCode isTrueDirect    medium  \
# 2             NaN        NaN  (not set)          NaN         True    (none)
# 9             NaN        NaN  (not set)          NaN         True   organic
# 29            NaN        NaN  (not set)          NaN         True   organic
# 31            NaN        NaN  (not set)          NaN         True   organic
# 35            NaN        NaN  (not set)          NaN         True   organic
# 41            NaN        NaN  (not set)          NaN         True    (none)
# 45            NaN        NaN  (not set)          NaN         True    (none)
# 56            NaN        NaN  (not set)          NaN         True    (none)
# 57            NaN        NaN  (not set)          NaN         True   organic
# 58            NaN        NaN  (not set)          NaN         True    (none)
# 59            NaN        NaN  (not set)          NaN         True    (none)
# 60            NaN        NaN  (not set)          NaN         True  referral
# 67            NaN        NaN  (not set)          NaN         True   organic
# 96            NaN        NaN  (not set)          NaN         True    (none)
# 101           NaN        NaN  (not set)          NaN         True   organic
# 105           NaN        NaN  (not set)          NaN         True   organic
# 107           NaN        NaN  (not set)          NaN         True   organic
# 110           NaN        NaN  (not set)          NaN         True    (none)
# 118           NaN        NaN  (not set)          NaN         True    (none)
# 119           NaN        NaN  (not set)          NaN         True    (none)
# 121           NaN        NaN  (not set)          NaN         True    (none)
# 165           NaN        NaN  (not set)          NaN         True   organic
# 166           NaN        NaN  (not set)          NaN         True   organic
# 181           NaN        NaN  (not set)          NaN         True    (none)
# 182           NaN        NaN  (not set)          NaN         True    (none)
# 185           NaN        NaN  (not set)          NaN         True    (none)
# 188           NaN        NaN  (not set)          NaN         True    (none)
# 193           NaN        NaN  (not set)          NaN         True   organic
# 195           NaN        NaN  (not set)          NaN         True    (none)
# 199           NaN        NaN  (not set)          NaN         True    (none)
# ...           ...        ...        ...          ...          ...       ...
# 1707987       NaN        NaN  (not set)          NaN         True    (none)
# 1707989       NaN        NaN  (not set)          NaN         True    (none)
# 1707990       NaN        NaN  (not set)          NaN         True    (none)
# 1707993       NaN        NaN  (not set)          NaN         True    (none)
# 1707996       NaN        NaN  (not set)          NaN         True    (none)
# 1707999       NaN        NaN  (not set)          NaN         True    (none)
# 1708000       NaN        NaN  (not set)          NaN         True    (none)
# 1708001       NaN        NaN  (not set)          NaN         True    (none)
# 1708004       NaN        NaN  (not set)          NaN         True  referral
# 1708014       NaN        NaN  (not set)          NaN         True  referral
# 1708018       NaN        NaN  (not set)          NaN         True  referral
# 1708074       NaN        NaN  (not set)          NaN         True  referral
# 1708123       NaN        NaN  (not set)          NaN         True  referral
# 1708127       NaN        NaN  (not set)          NaN         True  referral
# 1708160       NaN        NaN  (not set)          NaN         True  referral
# 1708176       NaN        NaN  (not set)          NaN         True  referral
# 1708182       NaN        NaN  (not set)          NaN         True  referral
# 1708194       NaN        NaN  (not set)          NaN         True  referral
# 1708205       NaN        NaN  (not set)          NaN         True  referral
# 1708225       NaN        NaN  (not set)          NaN         True  referral
# 1708226       NaN        NaN  (not set)          NaN         True  referral
# 1708227       NaN        NaN  (not set)          NaN         True  referral
# 1708250       NaN        NaN  (not set)          NaN         True  referral
# 1708253       NaN        NaN  (not set)          NaN         True  referral
# 1708289       NaN        NaN  (not set)          NaN         True  referral
# 1708291       NaN        NaN  (not set)          NaN         True  referral
# 1708299       NaN        NaN  (not set)          NaN         True  referral
# 1708306       NaN        NaN  (not set)          NaN         True  referral
# 1708320       NaN        NaN  (not set)          NaN         True  referral
# 1708327       NaN        NaN  (not set)          NaN         True  referral
#
#                     source channelGrouping fullVisitorId trafficSource  \
# 2                 (direct)             NaN           NaN           NaN
# 9                   google             NaN           NaN           NaN
# 29                  google             NaN           NaN           NaN
# 31                  google             NaN           NaN           NaN
# 35                  google             NaN           NaN           NaN
# 41                (direct)             NaN           NaN           NaN
# 45                (direct)             NaN           NaN           NaN
# 56                (direct)             NaN           NaN           NaN
# 57                  google             NaN           NaN           NaN
# 58                (direct)             NaN           NaN           NaN
# 59                (direct)             NaN           NaN           NaN
# 60         blog.golang.org             NaN           NaN           NaN
# 67                  google             NaN           NaN           NaN
# 96                (direct)             NaN           NaN           NaN
# 101                 google             NaN           NaN           NaN
# 105                 google             NaN           NaN           NaN
# 107                 google             NaN           NaN           NaN
# 110               (direct)             NaN           NaN           NaN
# 118               (direct)             NaN           NaN           NaN
# 119               (direct)             NaN           NaN           NaN
# 121               (direct)             NaN           NaN           NaN
# 165                 google             NaN           NaN           NaN
# 166                 google             NaN           NaN           NaN
# 181               (direct)             NaN           NaN           NaN
# 182               (direct)             NaN           NaN           NaN
# 185               (direct)             NaN           NaN           NaN
# 188               (direct)             NaN           NaN           NaN
# 193                 google             NaN           NaN           NaN
# 195               (direct)             NaN           NaN           NaN
# 199               (direct)             NaN           NaN           NaN
# ...                    ...             ...           ...           ...
# 1707987           (direct)             NaN           NaN           NaN
# 1707989           (direct)             NaN           NaN           NaN
# 1707990           (direct)             NaN           NaN           NaN
# 1707993           (direct)             NaN           NaN           NaN
# 1707996           (direct)             NaN           NaN           NaN
# 1707999           (direct)             NaN           NaN           NaN
# 1708000           (direct)             NaN           NaN           NaN
# 1708001           (direct)             NaN           NaN           NaN
# 1708004        youtube.com             NaN           NaN           NaN
# 1708014        youtube.com             NaN           NaN           NaN
# 1708018        youtube.com             NaN           NaN           NaN
# 1708074        youtube.com             NaN           NaN           NaN
# 1708123        youtube.com             NaN           NaN           NaN
# 1708127        youtube.com             NaN           NaN           NaN
# 1708160        youtube.com             NaN           NaN           NaN
# 1708176        youtube.com             NaN           NaN           NaN
# 1708182       facebook.com             NaN           NaN           NaN
# 1708194       facebook.com             NaN           NaN           NaN
# 1708205        youtube.com             NaN           NaN           NaN
# 1708225        youtube.com             NaN           NaN           NaN
# 1708226        youtube.com             NaN           NaN           NaN
# 1708227        youtube.com             NaN           NaN           NaN
# 1708250        youtube.com             NaN           NaN           NaN
# 1708253        youtube.com             NaN           NaN           NaN
# 1708289        youtube.com             NaN           NaN           NaN
# 1708291    plus.google.com             NaN           NaN           NaN
# 1708299       facebook.com             NaN           NaN           NaN
# 1708306        youtube.com             NaN           NaN           NaN
# 1708320       facebook.com             NaN           NaN           NaN
# 1708327  groups.google.com             NaN           NaN           NaN
#
#          visitNumber visitStartTime browser deviceCategory operatingSystem  \
# 2                NaN            NaT     NaN            NaN             NaN
# 9                NaN            NaT     NaN            NaN             NaN
# 29               NaN            NaT     NaN            NaN             NaN
# 31               NaN            NaT     NaN            NaN             NaN
# 35               NaN            NaT     NaN            NaN             NaN
# 41               NaN            NaT     NaN            NaN             NaN
# 45               NaN            NaT     NaN            NaN             NaN
# 56               NaN            NaT     NaN            NaN             NaN
# 57               NaN            NaT     NaN            NaN             NaN
# 58               NaN            NaT     NaN            NaN             NaN
# 59               NaN            NaT     NaN            NaN             NaN
# 60               NaN            NaT     NaN            NaN             NaN
# 67               NaN            NaT     NaN            NaN             NaN
# 96               NaN            NaT     NaN            NaN             NaN
# 101              NaN            NaT     NaN            NaN             NaN
# 105              NaN            NaT     NaN            NaN             NaN
# 107              NaN            NaT     NaN            NaN             NaN
# 110              NaN            NaT     NaN            NaN             NaN
# 118              NaN            NaT     NaN            NaN             NaN
# 119              NaN            NaT     NaN            NaN             NaN
# 121              NaN            NaT     NaN            NaN             NaN
# 165              NaN            NaT     NaN            NaN             NaN
# 166              NaN            NaT     NaN            NaN             NaN
# 181              NaN            NaT     NaN            NaN             NaN
# 182              NaN            NaT     NaN            NaN             NaN
# 185              NaN            NaT     NaN            NaN             NaN
# 188              NaN            NaT     NaN            NaN             NaN
# 193              NaN            NaT     NaN            NaN             NaN
# 195              NaN            NaT     NaN            NaN             NaN
# 199              NaN            NaT     NaN            NaN             NaN
# ...              ...            ...     ...            ...             ...
# 1707987          NaN            NaT     NaN            NaN             NaN
# 1707989          NaN            NaT     NaN            NaN             NaN
# 1707990          NaN            NaT     NaN            NaN             NaN
# 1707993          NaN            NaT     NaN            NaN             NaN
# 1707996          NaN            NaT     NaN            NaN             NaN
# 1707999          NaN            NaT     NaN            NaN             NaN
# 1708000          NaN            NaT     NaN            NaN             NaN
# 1708001          NaN            NaT     NaN            NaN             NaN
# 1708004          NaN            NaT     NaN            NaN             NaN
# 1708014          NaN            NaT     NaN            NaN             NaN
# 1708018          NaN            NaT     NaN            NaN             NaN
# 1708074          NaN            NaT     NaN            NaN             NaN
# 1708123          NaN            NaT     NaN            NaN             NaN
# 1708127          NaN            NaT     NaN            NaN             NaN
# 1708160          NaN            NaT     NaN            NaN             NaN
# 1708176          NaN            NaT     NaN            NaN             NaN
# 1708182          NaN            NaT     NaN            NaN             NaN
# 1708194          NaN            NaT     NaN            NaN             NaN
# 1708205          NaN            NaT     NaN            NaN             NaN
# 1708225          NaN            NaT     NaN            NaN             NaN
# 1708226          NaN            NaT     NaN            NaN             NaN
# 1708227          NaN            NaT     NaN            NaN             NaN
# 1708250          NaN            NaT     NaN            NaN             NaN
# 1708253          NaN            NaT     NaN            NaN             NaN
# 1708289          NaN            NaT     NaN            NaN             NaN
# 1708291          NaN            NaT     NaN            NaN             NaN
# 1708299          NaN            NaT     NaN            NaN             NaN
# 1708306          NaN            NaT     NaN            NaN             NaN
# 1708320          NaN            NaT     NaN            NaN             NaN
# 1708327          NaN            NaT     NaN            NaN             NaN
#
#         city country region subContinent timeOnSite  totalTransactionRevenue  \
# 2        NaN     NaN    NaN          NaN        NaN                      NaN
# 9        NaN     NaN    NaN          NaN        NaN                      NaN
# 29       NaN     NaN    NaN          NaN        NaN                      NaN
# 31       NaN     NaN    NaN          NaN        NaN                      NaN
# 35       NaN     NaN    NaN          NaN        NaN                      NaN
# 41       NaN     NaN    NaN          NaN        NaN                      NaN
# 45       NaN     NaN    NaN          NaN        NaN                      NaN
# 56       NaN     NaN    NaN          NaN        NaN                      NaN
# 57       NaN     NaN    NaN          NaN        NaN                      NaN
# 58       NaN     NaN    NaN          NaN        NaN                      NaN
# 59       NaN     NaN    NaN          NaN        NaN                      NaN
# 60       NaN     NaN    NaN          NaN        NaN                      NaN
# 67       NaN     NaN    NaN          NaN        NaN                      NaN
# 96       NaN     NaN    NaN          NaN        NaN                      NaN
# 101      NaN     NaN    NaN          NaN        NaN                      NaN
# 105      NaN     NaN    NaN          NaN        NaN                      NaN
# 107      NaN     NaN    NaN          NaN        NaN                      NaN
# 110      NaN     NaN    NaN          NaN        NaN                      NaN
# 118      NaN     NaN    NaN          NaN        NaN                      NaN
# 119      NaN     NaN    NaN          NaN        NaN                      NaN
# 121      NaN     NaN    NaN          NaN        NaN                      NaN
# 165      NaN     NaN    NaN          NaN        NaN                      NaN
# 166      NaN     NaN    NaN          NaN        NaN                      NaN
# 181      NaN     NaN    NaN          NaN        NaN                      NaN
# 182      NaN     NaN    NaN          NaN        NaN                      NaN
# 185      NaN     NaN    NaN          NaN        NaN                      NaN
# 188      NaN     NaN    NaN          NaN        NaN                      NaN
# 193      NaN     NaN    NaN          NaN        NaN                      NaN
# 195      NaN     NaN    NaN          NaN        NaN                      NaN
# 199      NaN     NaN    NaN          NaN        NaN                      NaN
# ...      ...     ...    ...          ...        ...                      ...
# 1707987  NaN     NaN    NaN          NaN        NaN                      NaN
# 1707989  NaN     NaN    NaN          NaN        NaN                      NaN
# 1707990  NaN     NaN    NaN          NaN        NaN                      NaN
# 1707993  NaN     NaN    NaN          NaN        NaN                      NaN
# 1707996  NaN     NaN    NaN          NaN        NaN                      NaN
# 1707999  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708000  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708001  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708004  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708014  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708018  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708074  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708123  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708127  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708160  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708176  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708182  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708194  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708205  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708225  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708226  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708227  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708250  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708253  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708289  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708291  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708299  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708306  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708320  NaN     NaN    NaN          NaN        NaN                      NaN
# 1708327  NaN     NaN    NaN          NaN        NaN                      NaN
#
#         transactions position
# 2                NaN      NaN
# 9                NaN      NaN
# 29               NaN      NaN
# 31               NaN      NaN
# 35               NaN      NaN
# 41               NaN      NaN
# 45               NaN      NaN
# 56               NaN      NaN
# 57               NaN      NaN
# 58               NaN      NaN
# 59               NaN      NaN
# 60               NaN      NaN
# 67               NaN      NaN
# 96               NaN      NaN
# 101              NaN      NaN
# 105              NaN      NaN
# 107              NaN      NaN
# 110              NaN      NaN
# 118              NaN      NaN
# 119              NaN      NaN
# 121              NaN      NaN
# 165              NaN      NaN
# 166              NaN      NaN
# 181              NaN      NaN
# 182              NaN      NaN
# 185              NaN      NaN
# 188              NaN      NaN
# 193              NaN      NaN
# 195              NaN      NaN
# 199              NaN      NaN
# ...              ...      ...
# 1707987          NaN      NaN
# 1707989          NaN      NaN
# 1707990          NaN      NaN
# 1707993          NaN      NaN
# 1707996          NaN      NaN
# 1707999          NaN      NaN
# 1708000          NaN      NaN
# 1708001          NaN      NaN
# 1708004          NaN      NaN
# 1708014          NaN      NaN
# 1708018          NaN      NaN
# 1708074          NaN      NaN
# 1708123          NaN      NaN
# 1708127          NaN      NaN
# 1708160          NaN      NaN
# 1708176          NaN      NaN
# 1708182          NaN      NaN
# 1708194          NaN      NaN
# 1708205          NaN      NaN
# 1708225          NaN      NaN
# 1708226          NaN      NaN
# 1708227          NaN      NaN
# 1708250          NaN      NaN
# 1708253          NaN      NaN
# 1708289          NaN      NaN
# 1708291          NaN      NaN
# 1708299          NaN      NaN
# 1708306          NaN      NaN
# 1708320          NaN      NaN
# 1708327          NaN      NaN
#
# [534518 rows x 23 columns]

# %%
df.to_csv("../data/test_v2_cleaned.csv")
df.to_pickle("../data/test_v2_cleaned.pkl")
