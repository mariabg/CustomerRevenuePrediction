# %%
import pandas as pd
import json
import os
import numpy as np
from pandas.io.json import json_normalize


def load_df(csv_path='./progetto finale/train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']

    df = pd.read_csv(csv_path,
                     converters={column: json.loads for column in JSON_COLUMNS},
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)

    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df



train_df = load_df()
df_test = load_df("./progetto finale/train.csv")
train_df=train_df.drop(["device.browserSize","device.browserVersion","device.flashVersion",
                       "device.language","device.mobileDeviceBranding","device.mobileDeviceInfo",
                       "device.mobileDeviceMarketingName","device.mobileDeviceModel",
                       "device.mobileInputSelector","device.operatingSystemVersion",
                       "device.screenColors","device.screenResolution","geoNetwork.cityId",
                       "geoNetwork.latitude","geoNetwork.longitude","geoNetwork.metro",
                       "geoNetwork.networkLocation","trafficSource.campaign","trafficSource.keyword","trafficSource.adwordsClickInfo.criteriaParameters"],axis=1)

df_test=df_test.drop(["device.browserSize","device.browserVersion","device.flashVersion",
                       "device.language","device.mobileDeviceBranding","device.mobileDeviceInfo",
                       "device.mobileDeviceMarketingName","device.mobileDeviceModel",
                       "device.mobileInputSelector","device.operatingSystemVersion",
                       "device.screenColors","device.screenResolution","geoNetwork.cityId",
                       "geoNetwork.latitude","geoNetwork.longitude","geoNetwork.metro",
                       "geoNetwork.networkLocation","trafficSource.campaign","trafficSource.keyword","trafficSource.adwordsClickInfo.criteriaParameters"],axis=1)

A=df_test.head(100)
# Out:
# Loaded train.csv. Shape: (903653, 55)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-805b5d0f8206> in <module>
#      24
#      25 train_df = load_df()
# ---> 26 df_test = load_df("./progetto finale/train.csv")
#      27 train_df=train_df.drop(["device.browserSize","device.browserVersion","device.flashVersion",
#      28                        "device.language","device.mobileDeviceBranding","device.mobileDeviceInfo",
#
# <ipython-input-1-805b5d0f8206> in load_df(csv_path, nrows)
#      15
#      16     for column in JSON_COLUMNS:
# ---> 17         column_as_df = json_normalize(df[column])
#      18         column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
#      19         df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
#
# ...

# %% [markdown]
# df_test.shape() Perchè mi da errore???

# %%
A.to_csv("Vedicose.csv",sep=';', encoding='utf-8', index=False)

# %% [markdown]
# Le colonne con il valore   "not available in demo dataset!" sono:
# - device.browserSize
# - device.browserVersion
# - device.flashVersion
# - device.language
# - device.mobileDeviceBranding
# - device.mobileDeviceInfo
# - device.mobileDeviceMarketingName
# - device.mobileDeviceModel
# - device.mobileInputSelector
# - device.operatingSystemVersion
# - device.screenColors
# - device.screenResolution
# - geoNetwork.cityId
# - geoNetwork.latitude
# - geoNetwork.longitude
# - geoNetwork.metro
# - geoNetwork.networkLocation
# - trafficSource.campaign
# - trafficSource.keyword
# - trafficSource.adwordsClickInfo.criteriaParameters
# Probably for privacy reasons -20 colonne

# %% [markdown]
# Analisi attributi:
#
# Id actrbute:
# - fullVisitorId
# - sessionId
# - socialEngagementType
# - visitId
#
# Access informations: Christian
# - channelGrouping
# - date
# - fullVisitorId
# - sessionId
# - socialEngagementType
# - visitId
# - visitNumber
# - visitStartTime
#
# Platform of access : Mathias
# - device.browser
# - device.deviceCategory
# - device.isMobile
# - device.operatingSystem
#
# Geo parameters: Dario
# - geoNetwork.city-
# - geoNetwork.continent
# - geoNetwork.country
# - geoNetwork.networkDomain
# - geoNetwork.region
# - geoNetwork.subContinent
#
# Online/platforme actributes: Miguel
# - totals.bounces
# - totals.hits
# - totals.newVisits
# - totals.pageviews
# - totals.transactionRevenue
# - totals.visits
#
# Traffic source parameters: MAria
# - trafficSource.adContent
# - trafficSource.adwordsClickInfo.adNetworkType
# - trafficSource.adwordsClickInfo.gclId
# - trafficSource.adwordsClickInfo.isVideoAd
# - trafficSource.adwordsClickInfo.page
# - trafficSource.adwordsClickInfo.slot
# - trafficSource.isTrueDirect
# - trafficSource.medium
# - trafficSource.referralPath
# - trafficSource.source

# %%
A=df_test.head(100)

# %%
# Out:
#       channelGrouping      date        fullVisitorId  \
# 0      Organic Search  20160902  1131660440785968503
# 1      Organic Search  20160902   377306020877927890
# 2      Organic Search  20160902  3895546263509774583
# 3      Organic Search  20160902  4763447161404445595
# 4      Organic Search  20160902    27294437909732085
# 5      Organic Search  20160902  2938943183656635653
# 6      Organic Search  20160902  1905672039242460897
# 7      Organic Search  20160902   537222803633850821
# 8      Organic Search  20160902  4445454811831400414
# 9      Organic Search  20160902  9499785259412240342
# 10     Organic Search  20160902  0523069750702990437
# 11     Organic Search  20160902   982320996976275749
# 12     Organic Search  20160902   357659889600827884
# 13     Organic Search  20160902  1438082600262726746
# 14     Organic Search  20160902  3531015320757710684
# 15     Organic Search  20160902  9638207207743070032
# 16     Organic Search  20160902  9876750586615598787
# ...

# %% [markdown]
# Non ci sono caselle completamente nulle

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-193753be380d> in <module>
# ----> 1 train_df.head()
#
# NameError: name 'train_df' is not defined
